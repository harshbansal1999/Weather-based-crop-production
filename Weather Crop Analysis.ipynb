# %%
#Loading of necessary libraries fo analysis and visualizations
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Loading of Data in dataframe form
df1=pd.read_csv('Weather.csv')
df2=pd.read_csv('crop.csv')

# %%
df1.head()
# Out:
#    Unnamed: 0      city        date  year  month  day  high_temp  avg_temp  \
# 0           1  Auckland  2016-01-01  2016      1    1         68        65
# 1           2  Auckland  2016-01-02  2016      1    2         68        66
# 2           3  Auckland  2016-01-03  2016      1    3         77        72
# 3           4  Auckland  2016-01-04  2016      1    4         73        66
# 4           5  Auckland  2016-01-05  2016      1    5         69        62
#
#    low_temp  high_dewpt  ...  avg_hg  low_hg  high_vis  avg_vis  low_vis  \
# 0        62          64  ...   30.09   30.01         6        6        4
# 1        64          64  ...   29.90   29.80         6        5        1
# 2        66          70  ...   29.73   29.68         6        6        1
# 3        60          66  ...   29.90   29.77         6        6        6
# 4        55          55  ...   30.14   30.09         6        6        6
#
#    high_wind  avg_wind  low_wind  precip  events
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3655 entries, 0 to 3654
# Data columns (total 26 columns):
# Unnamed: 0       3655 non-null int64
# city             3655 non-null object
# date             3655 non-null object
# year             3655 non-null int64
# month            3655 non-null int64
# day              3655 non-null int64
# high_temp        3655 non-null int64
# avg_temp         3655 non-null int64
# low_temp         3655 non-null int64
# high_dewpt       3655 non-null int64
# avg_dewpt        3655 non-null int64
# low_dewpt        3655 non-null int64
# high_humidity    3655 non-null int64
# avg_humidity     3655 non-null int64
# low_humidity     3655 non-null int64
# high_hg          3655 non-null float64
# avg_hg           3655 non-null float64
# low_hg           3655 non-null float64
# high_vis         3655 non-null int64
# avg_vis          3655 non-null int64
# low_vis          3655 non-null int64
# high_wind        3655 non-null int64
# ...

# %%
df1.describe()
# Out:
#         Unnamed: 0         year        month          day    high_temp  \
# count  3655.000000  3655.000000  3655.000000  3655.000000  3655.000000
# mean   1828.000000  2016.499316     6.519836    15.738714    71.324213
# std    1055.251945     0.500068     3.450023     8.805125    17.191863
# min       1.000000  2016.000000     1.000000     1.000000     5.000000
# 25%     914.500000  2016.000000     4.000000     8.000000    62.000000
# 50%    1828.000000  2016.000000     7.000000    16.000000    73.000000
# 75%    2741.500000  2017.000000    10.000000    23.000000    86.000000
# max    3655.000000  2017.000000    12.000000    31.000000   102.000000
#
#           avg_temp     low_temp   high_dewpt    avg_dewpt    low_dewpt  ...  \
# count  3655.000000  3655.000000  3655.000000  3655.000000  3655.000000  ...
# mean     63.255540    54.951847    55.966895    50.989056    45.409302  ...
# std      16.676592    17.106124    17.651874    19.105027    20.754763  ...
# ...

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0          0
# city                0
# date                0
# year                0
# month               0
# day                 0
# high_temp           0
# avg_temp            0
# low_temp            0
# high_dewpt          0
# avg_dewpt           0
# low_dewpt           0
# high_humidity       0
# avg_humidity        0
# low_humidity        0
# high_hg             0
# avg_hg              0
# low_hg              0
# high_vis            0
# avg_vis             0
# low_vis             0
# high_wind           0
# avg_wind            0
# low_wind         1326
# precip              0
# events           2217
# dtype: int64

# %%
#Data Pre-Processing and cleaning

# %%
#Dealing with null values
df1['low_wind']=df1['low_wind'].fillna(df1['low_wind'].mean())
df1['events']=df1['events'].fillna('Not Specified')

# %%
df1['low_wind']=df1['low_wind'].astype(int)

# %%
def f(x):
    x=(x-32)*0.5
    return int(x)

# %%
#Change temperature in Farhenheit to Celcius
df1['high_temp']=df1['high_temp'].apply(f)
df1['low_temp']=df1['low_temp'].apply(f)

# %%
df1['Temp Diff']=df1['high_temp']-df1['low_temp']
df2['Temp Diff']=df2['Max Temp']-df2['Min Temp']

# %%
df1['city'].value_counts()
# Out:
# San Diego    731
# Auckland     731
# Mumbai       731
# Beijing      731
# Chicago      731
# Name: city, dtype: int64

# %%
df1['month'].value_counts()
# Out:
# 7     310
# 5     310
# 3     310
# 1     310
# 12    310
# 10    310
# 8     310
# 11    300
# 9     300
# 6     300
# 4     300
# 2     285
# Name: month, dtype: int64

# %%
df2
# Out:
#           Crop     Season  Rainfall Min   Rainfall Max  Relative Humidity Max  \
# 0        Apple  Perennial          1000           1250                     70
# 1       Banana     Kharif          1200           2200                     75
# 2       Barley       Rabi           650            900                     70
# 3         Bean     Kharif           300            500                     50
# 4   Black Gram     Kharif           700            950                     65
# 5      Brinjal       Rabi           400            600                     75
# 6      Cabbage     Kharif           380            500                     85
# 7    Cashewnut  Perennial          1000           2000                     85
# 8       Castor     Kharif           500            800                     45
# 9     Chillies       Rabi           850           1200                     50
# 10      Citrus  Perennial           900           1200                     75
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 11 columns):
# Crop                       13 non-null object
# Season                     13 non-null object
# Rainfall Min               13 non-null int64
#  Rainfall Max              13 non-null int64
# Relative Humidity Max      13 non-null int64
# Relative Humidity Max.1    13 non-null int64
# Min Temp                   13 non-null int64
# Max Temp                   13 non-null int64
# pH Min                     13 non-null float64
# pH Max                     13 non-null float64
# Temp Diff                  13 non-null int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 1.2+ KB

# %%
df2.describe()
# Out:
#        Rainfall Min   Rainfall Max  Relative Humidity Max  \
# count     13.000000      13.000000              13.000000
# mean     717.692308    1100.000000              67.307692
# std      271.696947     521.616078              12.847728
# min      300.000000     500.000000              45.000000
# 25%      500.000000     800.000000              60.000000
# 50%      700.000000     950.000000              70.000000
# 75%      900.000000    1250.000000              75.000000
# max     1200.000000    2200.000000              85.000000
#
#        Relative Humidity Max.1   Min Temp   Max Temp     pH Min     pH Max  \
# count                13.000000  13.000000  13.000000  13.000000  13.000000
# mean                 78.846154  17.384615  25.615385   7.715385   7.253846
# std                  11.574729   5.252594   5.315676   6.122615   0.738935
# min                  60.000000   5.000000  15.000000   5.500000   6.000000
# ...

# %%
#Auckland Month Wise Temperature
print('January(MIN):',df1.loc[(df1['city']=='Auckland') & (df1['month']==1),'low_temp'].mean()) 
print('January(MAX):',df1.loc[(df1['city']=='Auckland') & (df1['month']==1),'high_temp'].mean()) 
print('Feb(MIN):',df1.loc[(df1['city']=='Auckland') & (df1['month']==2),'low_temp'].mean()) 
print('Feb(MAX):',df1.loc[(df1['city']=='Auckland') & (df1['month']==2),'high_temp'].mean())
print('March(MIN):',df1.loc[(df1['city']=='Auckland') & (df1['month']==3),'low_temp'].mean()) 
print('March(Max):',df1.loc[(df1['city']=='Auckland') & (df1['month']==3),'high_temp'].mean())
print('April(MIN):',df1.loc[(df1['city']=='Auckland') & (df1['month']==4),'low_temp'].mean())  
print('April(Max):',df1.loc[(df1['city']=='Auckland') & (df1['month']==4),'high_temp'].mean())
print('May(MIN):',df1.loc[(df1['city']=='Auckland') & (df1['month']==5),'low_temp'].mean()) 
print('May(Max):',df1.loc[(df1['city']=='Auckland') & (df1['month']==5),'high_temp'].mean())
print('June(MIN):',df1.loc[(df1['city']=='Auckland') & (df1['month']==6),'low_temp'].mean())
print('June(Max):',df1.loc[(df1['city']=='Auckland') & (df1['month']==6),'high_temp'].mean())
print('July(MIN):',df1.loc[(df1['city']=='Auckland') & (df1['month']==7),'low_temp'].mean())
print('July(Max):',df1.loc[(df1['city']=='Auckland') & (df1['month']==7),'high_temp'].mean())
print('August(MIN):',df1.loc[(df1['city']=='Auckland') & (df1['month']==8),'low_temp'].mean())
print('August(MAX):',df1.loc[(df1['city']=='Auckland') & (df1['month']==8),'high_temp'].mean())
print('September(MIN):',df1.loc[(df1['city']=='Auckland') & (df1['month']==9),'low_temp'].mean())
print('September(MAX):',df1.loc[(df1['city']=='Auckland') & (df1['month']==9),'high_temp'].mean())
print('October(MIN):',df1.loc[(df1['city']=='Auckland') & (df1['month']==10),'low_temp'].mean())
print('October(MAX):',df1.loc[(df1['city']=='Auckland') & (df1['month']==10),'high_temp'].mean())
print('November(MIN):',df1.loc[(df1['city']=='Auckland') & (df1['month']==11),'low_temp'].mean())
print('November(MAX):',df1.loc[(df1['city']=='Auckland') & (df1['month']==11),'high_temp'].mean())
print('December(MIN):',df1.loc[(df1['city']=='Auckland') & (df1['month']==12),'low_temp'].mean())
print('December(MAX):',df1.loc[(df1['city']=='Auckland') & (df1['month']==12),'high_temp'].mean())
# Out:
# January(MIN): 14.5
# January(MAX): 20.35483870967742
# Feb(MIN): 15.43859649122807
# Feb(MAX): 21.70175438596491
# March(MIN): 14.516129032258064
# March(Max): 19.983870967741936
# April(MIN): 11.95
# April(Max): 18.316666666666666
# May(MIN): 9.919354838709678
# May(Max): 16.177419354838708
# June(MIN): 7.966666666666667
# June(Max): 13.8
# July(MIN): 7.161290322580645
# July(Max): 12.596774193548388
# August(MIN): 7.5
# August(MAX): 13.370967741935484
# September(MIN): 9.25
# September(MAX): 14.483333333333333
# October(MIN): 10.516129032258064
# October(MAX): 15.741935483870968
# November(MIN): 11.35
# November(MAX): 17.516666666666666
# December(MIN): 13.306451612903226
# December(MAX): 19.967741935483872

# %%
#San Diego Month Wise Temperature
print('January(MIN):',df1.loc[(df1['city']=='San Diego') & (df1['month']==1),'low_temp'].mean()) 
print('January(MAX):',df1.loc[(df1['city']=='San Diego') & (df1['month']==1),'high_temp'].mean()) 
print('Feb(MIN):',df1.loc[(df1['city']=='San Diego') & (df1['month']==2),'low_temp'].mean()) 
print('Feb(MAX):',df1.loc[(df1['city']=='San Diego') & (df1['month']==2),'high_temp'].mean())
print('March(MIN):',df1.loc[(df1['city']=='San Diego') & (df1['month']==3),'low_temp'].mean())
print('March(Max):',df1.loc[(df1['city']=='San Diego') & (df1['month']==3),'high_temp'].mean())
print('April(MIN):',df1.loc[(df1['city']=='San Diego') & (df1['month']==4),'low_temp'].mean())
print('April(Max):',df1.loc[(df1['city']=='San Diego') & (df1['month']==4),'high_temp'].mean())
print('May(MIN):',df1.loc[(df1['city']=='San Diego') & (df1['month']==5),'low_temp'].mean())
print('May(Max):',df1.loc[(df1['city']=='San Diego') & (df1['month']==5),'high_temp'].mean())
print('June(MIN):',df1.loc[(df1['city']=='San Diego') & (df1['month']==6),'low_temp'].mean())
print('June(Max):',df1.loc[(df1['city']=='San Diego') & (df1['month']==6),'high_temp'].mean())
print('July(MIN):',df1.loc[(df1['city']=='San Diego') & (df1['month']==7),'low_temp'].mean())
print('July(Max):',df1.loc[(df1['city']=='San Diego') & (df1['month']==7),'high_temp'].mean())
print('August(MIN):',df1.loc[(df1['city']=='San Diego') & (df1['month']==8),'low_temp'].mean())
print('August(MAX):',df1.loc[(df1['city']=='San Diego') & (df1['month']==8),'high_temp'].mean())
print('September(MIN):',df1.loc[(df1['city']=='San Diego') & (df1['month']==9),'low_temp'].mean())
print('September(MAX):',df1.loc[(df1['city']=='San Diego') & (df1['month']==9),'high_temp'].mean())
print('October(MIN):',df1.loc[(df1['city']=='San Diego') & (df1['month']==10),'low_temp'].mean())
print('October(MAX):',df1.loc[(df1['city']=='San Diego') & (df1['month']==10),'high_temp'].mean())
print('November(MIN):',df1.loc[(df1['city']=='San Diego') & (df1['month']==11),'low_temp'].mean())
print('November(MAX):',df1.loc[(df1['city']=='San Diego') & (df1['month']==11),'high_temp'].mean())
print('December(MIN):',df1.loc[(df1['city']=='San Diego') & (df1['month']==12),'low_temp'].mean())
print('December(MAX):',df1.loc[(df1['city']=='San Diego') & (df1['month']==12),'high_temp'].mean())
# Out:
# January(MIN): 9.64516129032258
# January(MAX): 16.112903225806452
# Feb(MIN): 10.807017543859649
# Feb(MAX): 18.719298245614034
# March(MIN): 11.85483870967742
# March(Max): 18.43548387096774
# April(MIN): 13.116666666666667
# April(Max): 19.75
# May(MIN): 14.096774193548388
# May(Max): 18.370967741935484
# June(MIN): 15.533333333333333
# June(Max): 20.4
# July(MIN): 17.467741935483872
# July(Max): 22.06451612903226
# August(MIN): 17.903225806451612
# August(MAX): 22.596774193548388
# September(MIN): 17.216666666666665
# September(MAX): 22.966666666666665
# October(MIN): 15.612903225806452
# October(MAX): 22.741935483870968
# November(MIN): 12.466666666666667
# November(MAX): 20.533333333333335
# December(MIN): 9.080645161290322
# December(MAX): 18.080645161290324

# %%
#Mumbai Month Wise Temperature
print('January(MIN):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==1),'low_temp'].mean())
print('January(MAX):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==1),'high_temp'].mean())
print('Feb(MIN):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==2),'low_temp'].mean()) 
print('Feb(MAX):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==2),'high_temp'].mean())
print('March(MIN):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==3),'low_temp'].mean())
print('March(Max):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==3),'high_temp'].mean())
print('April(MIN):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==4),'low_temp'].mean())
print('April(Max):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==4),'high_temp'].mean())
print('May(MIN):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==5),'low_temp'].mean())
print('May(Max):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==5),'high_temp'].mean())
print('June(MIN):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==6),'low_temp'].mean())
print('June(Max):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==6),'high_temp'].mean())
print('July(MIN):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==7),'low_temp'].mean())
print('July(Max):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==7),'high_temp'].mean())
print('August(MIN):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==8),'low_temp'].mean())
print('August(MAX):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==8),'high_temp'].mean())
print('September(MIN):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==9),'low_temp'].mean())
print('September(MAX):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==9),'high_temp'].mean())
print('October(MIN):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==10),'low_temp'].mean())
print('October(MAX):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==10),'high_temp'].mean())
print('November(MIN):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==11),'low_temp'].mean())
print('November(MAX):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==11),'high_temp'].mean())
print('December(MIN):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==12),'low_temp'].mean())
print('December(MAX):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==12),'high_temp'].mean())
# Out:
# January(MIN): 14.14516129032258
# January(MAX): 28.096774193548388
# Feb(MIN): 15.859649122807017
# Feb(MAX): 28.43859649122807
# March(MIN): 18.661290322580644
# March(Max): 29.741935483870968
# April(MIN): 21.1
# April(Max): 29.9
# May(MIN): 23.661290322580644
# May(Max): 30.258064516129032
# June(MIN): 23.133333333333333
# June(Max): 28.983333333333334
# July(MIN): 21.822580645161292
# July(Max): 26.79032258064516
# August(MIN): 22.048387096774192
# August(MAX): 26.838709677419356
# September(MIN): 21.666666666666668
# September(MAX): 27.333333333333332
# October(MIN): 20.951612903225808
# October(MAX): 29.258064516129032
# November(MIN): 17.3
# November(MAX): 30.55
# December(MIN): 15.709677419354838
# December(MAX): 28.79032258064516

# %%
#Beijing Month Wise Temperature
print('January(MIN):',df1.loc[(df1['city']=='Beijing') & (df1['month']==1),'low_temp'].mean()) 
print('January(MAX):',df1.loc[(df1['city']=='Beijing') & (df1['month']==1),'high_temp'].mean())
print('Feb(MIN):',df1.loc[(df1['city']=='Beijing') & (df1['month']==2),'low_temp'].mean())
print('Feb(MAX):',df1.loc[(df1['city']=='Beijing') & (df1['month']==2),'high_temp'].mean())
print('March(MIN):',df1.loc[(df1['city']=='Beijing') & (df1['month']==3),'low_temp'].mean())
print('March(Max):',df1.loc[(df1['city']=='Beijing') & (df1['month']==3),'high_temp'].mean())
print('April(MIN):',df1.loc[(df1['city']=='Beijing') & (df1['month']==4),'low_temp'].mean())
print('April(Max):',df1.loc[(df1['city']=='Beijing') & (df1['month']==4),'high_temp'].mean())
print('May(MIN):',df1.loc[(df1['city']=='Beijing') & (df1['month']==5),'low_temp'].mean())
print('May(Max):',df1.loc[(df1['city']=='Beijing') & (df1['month']==5),'high_temp'].mean())
print('June(MIN):',df1.loc[(df1['city']=='Beijing') & (df1['month']==6),'low_temp'].mean())
print('June(Max):',df1.loc[(df1['city']=='Beijing') & (df1['month']==6),'high_temp'].mean())
print('July(MIN):',df1.loc[(df1['city']=='Beijing') & (df1['month']==7),'low_temp'].mean())
print('July(Max):',df1.loc[(df1['city']=='Beijing') & (df1['month']==7),'high_temp'].mean())
print('August(MIN):',df1.loc[(df1['city']=='Beijing') & (df1['month']==8),'low_temp'].mean())
print('August(MAX):',df1.loc[(df1['city']=='Beijing') & (df1['month']==8),'high_temp'].mean())
print('September(MIN):',df1.loc[(df1['city']=='Beijing') & (df1['month']==9),'low_temp'].mean())
print('September(MAX):',df1.loc[(df1['city']=='Beijing') & (df1['month']==9),'high_temp'].mean())
print('October(MIN):',df1.loc[(df1['city']=='Beijing') & (df1['month']==10),'low_temp'].mean())
print('October(MAX):',df1.loc[(df1['city']=='Beijing') & (df1['month']==10),'high_temp'].mean())
print('November(MIN):',df1.loc[(df1['city']=='Beijing') & (df1['month']==11),'low_temp'].mean())
print('November(MAX):',df1.loc[(df1['city']=='Beijing') & (df1['month']==11),'high_temp'].mean())
print('December(MIN):',df1.loc[(df1['city']=='Beijing') & (df1['month']==12),'low_temp'].mean())
print('December(MAX):',df1.loc[(df1['city']=='Beijing') & (df1['month']==12),'high_temp'].mean())
# Out:
# January(MIN): -8.35483870967742
# January(MAX): 1.467741935483871
# Feb(MIN): -5.0
# Feb(MAX): 6.4035087719298245
# March(MIN): 0.24193548387096775
# March(Max): 13.03225806451613
# April(MIN): 6.766666666666667
# April(Max): 20.7
# May(MIN): 11.774193548387096
# May(Max): 25.64516129032258
# June(MIN): 16.2
# June(Max): 27.85
# July(MIN): 20.0
# July(Max): 28.274193548387096
# August(MIN): 18.612903225806452
# August(MAX): 28.129032258064516
# September(MIN): 13.683333333333334
# September(MAX): 24.633333333333333
# October(MIN): 6.661290322580645
# October(MAX): 15.5
# November(MIN): -2.25
# November(MAX): 8.1
# December(MIN): -6.080645161290323
# December(MAX): 4.290322580645161

# %%
#Chicago Month Wise Temperature
print('January(MIN):',df1.loc[(df1['city']=='Chicago') & (df1['month']==1),'low_temp'].mean())
print('January(MAX):',df1.loc[(df1['city']=='Chicago') & (df1['month']==1),'high_temp'].mean())
print('Feb(MIN):',df1.loc[(df1['city']=='Chicago') & (df1['month']==2),'low_temp'].mean())
print('Feb(MAX):',df1.loc[(df1['city']=='Chicago') & (df1['month']==2),'high_temp'].mean())
print('March(MIN):',df1.loc[(df1['city']=='Chicago') & (df1['month']==3),'low_temp'].mean())
print('March(Max):',df1.loc[(df1['city']=='Chicago') & (df1['month']==3),'high_temp'].mean())
print('April(MIN):',df1.loc[(df1['city']=='Chicago') & (df1['month']==4),'low_temp'].mean())
print('April(Max):',df1.loc[(df1['city']=='Chicago') & (df1['month']==4),'high_temp'].mean())
print('May(MIN):',df1.loc[(df1['city']=='Chicago') & (df1['month']==5),'low_temp'].mean())
print('May(Max):',df1.loc[(df1['city']=='Chicago') & (df1['month']==5),'high_temp'].mean())
print('June(MIN):',df1.loc[(df1['city']=='Chicago') & (df1['month']==6),'low_temp'].mean())
print('June(Max):',df1.loc[(df1['city']=='Chicago') & (df1['month']==6),'high_temp'].mean())
print('July(MIN):',df1.loc[(df1['city']=='Chicago') & (df1['month']==7),'low_temp'].mean())
print('July(Max):',df1.loc[(df1['city']=='Chicago') & (df1['month']==7),'high_temp'].mean())
print('August(MIN):',df1.loc[(df1['city']=='Chicago') & (df1['month']==8),'low_temp'].mean())
print('August(MAX):',df1.loc[(df1['city']=='Chicago') & (df1['month']==8),'high_temp'].mean())
print('September(MIN):',df1.loc[(df1['city']=='Chicago') & (df1['month']==9),'low_temp'].mean())
print('September(MAX):',df1.loc[(df1['city']=='Chicago') & (df1['month']==9),'high_temp'].mean())
print('October(MIN):',df1.loc[(df1['city']=='Chicago') & (df1['month']==10),'low_temp'].mean())
print('October(MAX):',df1.loc[(df1['city']=='Chicago') & (df1['month']==10),'high_temp'].mean())
print('November(MIN):',df1.loc[(df1['city']=='Chicago') & (df1['month']==11),'low_temp'].mean())
print('November(MAX):',df1.loc[(df1['city']=='Chicago') & (df1['month']==11),'high_temp'].mean())
print('December(MIN):',df1.loc[(df1['city']=='Chicago') & (df1['month']==12),'low_temp'].mean())
print('December(MAX):',df1.loc[(df1['city']=='Chicago') & (df1['month']==12),'high_temp'].mean())
# Out:
# January(MIN): -5.693548387096774
# January(MAX): 0.532258064516129
# Feb(MIN): -2.912280701754386
# Feb(MAX): 5.035087719298246
# March(MIN): 0.7096774193548387
# March(Max): 8.419354838709678
# April(MIN): 4.25
# April(Max): 14.066666666666666
# May(MIN): 8.112903225806452
# May(Max): 18.129032258064516
# June(MIN): 14.45
# June(Max): 25.05
# July(MIN): 16.806451612903224
# July(Max): 25.806451612903224
# August(MIN): 16.177419354838708
# August(MAX): 25.096774193548388
# September(MIN): 13.966666666666667
# September(MAX): 23.1
# October(MIN): 8.161290322580646
# October(MAX): 16.580645161290324
# November(MIN): 1.6166666666666667
# November(MAX): 9.316666666666666
# December(MIN): -6.048387096774194
# December(MAX): 0.3064516129032258

# %%
#Auckland Month Wise Humidity
print('January(MIN):',df1.loc[(df1['city']=='Auckland') & (df1['month']==1),'low_humidity'].mean())
print('January(MAX):',df1.loc[(df1['city']=='Auckland') & (df1['month']==1),'high_humidity'].mean()) 
print('Feb(MIN):',df1.loc[(df1['city']=='Auckland') & (df1['month']==2),'low_humidity'].mean()) 
print('Feb(MAX):',df1.loc[(df1['city']=='Auckland') & (df1['month']==2),'high_humidity'].mean())
print('March(MIN):',df1.loc[(df1['city']=='Auckland') & (df1['month']==3),'low_humidity'].mean())
print('March(Max):',df1.loc[(df1['city']=='Auckland') & (df1['month']==3),'high_humidity'].mean())
print('April(MIN):',df1.loc[(df1['city']=='Auckland') & (df1['month']==4),'low_humidity'].mean())  
print('April(Max):',df1.loc[(df1['city']=='Auckland') & (df1['month']==4),'high_humidity'].mean())
print('May(MIN):',df1.loc[(df1['city']=='Auckland') & (df1['month']==5),'low_humidity'].mean())
print('May(Max):',df1.loc[(df1['city']=='Auckland') & (df1['month']==5),'high_humidity'].mean())
print('June(MIN):',df1.loc[(df1['city']=='Auckland') & (df1['month']==6),'low_humidity'].mean())
print('June(Max):',df1.loc[(df1['city']=='Auckland') & (df1['month']==6),'high_humidity'].mean())
print('July(MIN):',df1.loc[(df1['city']=='Auckland') & (df1['month']==7),'low_humidity'].mean())
print('July(Max):',df1.loc[(df1['city']=='Auckland') & (df1['month']==7),'high_humidity'].mean())
print('August(MIN):',df1.loc[(df1['city']=='Auckland') & (df1['month']==8),'low_humidity'].mean())
print('August(MAX):',df1.loc[(df1['city']=='Auckland') & (df1['month']==8),'high_humidity'].mean())
print('September(MIN):',df1.loc[(df1['city']=='Auckland') & (df1['month']==9),'low_humidity'].mean())
print('September(MAX):',df1.loc[(df1['city']=='Auckland') & (df1['month']==9),'high_humidity'].mean())
print('October(MIN):',df1.loc[(df1['city']=='Auckland') & (df1['month']==10),'low_humidity'].mean())
print('October(MAX):',df1.loc[(df1['city']=='Auckland') & (df1['month']==10),'high_humidity'].mean())
print('November(MIN):',df1.loc[(df1['city']=='Auckland') & (df1['month']==11),'low_humidity'].mean())
print('November(MAX):',df1.loc[(df1['city']=='Auckland') & (df1['month']==11),'high_humidity'].mean())
print('December(MIN):',df1.loc[(df1['city']=='Auckland') & (df1['month']==12),'low_humidity'].mean())
print('December(MAX):',df1.loc[(df1['city']=='Auckland') & (df1['month']==12),'high_humidity'].mean())
# Out:
# January(MIN): 58.145161290322584
# January(MAX): 92.66129032258064
# Feb(MIN): 60.59649122807018
# Feb(MAX): 94.19298245614036
# March(MIN): 62.67741935483871
# March(Max): 95.48387096774194
# April(MIN): 63.53333333333333
# April(Max): 96.73333333333333
# May(MIN): 64.70967741935483
# May(Max): 97.91935483870968
# June(MIN): 69.23333333333333
# June(Max): 98.05
# July(MIN): 67.64516129032258
# July(Max): 96.98387096774194
# August(MIN): 66.53225806451613
# August(MAX): 96.69354838709677
# September(MIN): 65.8
# September(MAX): 96.11666666666666
# October(MIN): 65.20967741935483
# October(MAX): 93.88709677419355
# November(MIN): 58.56666666666667
# November(MAX): 92.65
# December(MIN): 54.61290322580645
# December(MAX): 91.37096774193549

# %%
#San Diego Month Wise Humidity
print('January(MIN):',df1.loc[(df1['city']=='San Diego') & (df1['month']==1),'low_humidity'].mean())
print('January(MAX):',df1.loc[(df1['city']=='San Diego') & (df1['month']==1),'high_humidity'].mean()) 
print('Feb(MIN):',df1.loc[(df1['city']=='San Diego') & (df1['month']==2),'low_humidity'].mean()) 
print('Feb(MAX):',df1.loc[(df1['city']=='San Diego') & (df1['month']==2),'high_humidity'].mean())
print('March(MIN):',df1.loc[(df1['city']=='San Diego') & (df1['month']==3),'low_humidity'].mean())
print('March(Max):',df1.loc[(df1['city']=='San Diego') & (df1['month']==3),'high_humidity'].mean())
print('April(MIN):',df1.loc[(df1['city']=='San Diego') & (df1['month']==4),'low_humidity'].mean())
print('April(Max):',df1.loc[(df1['city']=='San Diego') & (df1['month']==4),'high_humidity'].mean())
print('May(MIN):',df1.loc[(df1['city']=='San Diego') & (df1['month']==5),'low_humidity'].mean())
print('May(Max):',df1.loc[(df1['city']=='San Diego') & (df1['month']==5),'high_humidity'].mean())
print('June(MIN):',df1.loc[(df1['city']=='San Diego') & (df1['month']==6),'low_humidity'].mean())
print('June(Max):',df1.loc[(df1['city']=='San Diego') & (df1['month']==6),'high_humidity'].mean())
print('July(MIN):',df1.loc[(df1['city']=='San Diego') & (df1['month']==7),'low_humidity'].mean())
print('July(Max):',df1.loc[(df1['city']=='San Diego') & (df1['month']==7),'high_humidity'].mean())
print('August(MIN):',df1.loc[(df1['city']=='San Diego') & (df1['month']==8),'low_humidity'].mean())
print('August(MAX):',df1.loc[(df1['city']=='San Diego') & (df1['month']==8),'high_humidity'].mean())
print('September(MIN):',df1.loc[(df1['city']=='San Diego') & (df1['month']==9),'low_humidity'].mean())
print('September(MAX):',df1.loc[(df1['city']=='San Diego') & (df1['month']==9),'high_humidity'].mean())
print('October(MIN):',df1.loc[(df1['city']=='San Diego') & (df1['month']==10),'low_humidity'].mean())
print('October(MAX):',df1.loc[(df1['city']=='San Diego') & (df1['month']==10),'high_humidity'].mean())
print('November(MIN):',df1.loc[(df1['city']=='San Diego') & (df1['month']==11),'low_humidity'].mean())
print('November(MAX):',df1.loc[(df1['city']=='San Diego') & (df1['month']==11),'high_humidity'].mean())
print('December(MIN):',df1.loc[(df1['city']=='San Diego') & (df1['month']==12),'low_humidity'].mean())
print('December(MAX):',df1.loc[(df1['city']=='San Diego') & (df1['month']==12),'high_humidity'].mean())
# Out:
# January(MIN): 48.435483870967744
# January(MAX): 79.79032258064517
# Feb(MIN): 42.175438596491226
# Feb(MAX): 74.35087719298245
# March(MIN): 46.32258064516129
# March(Max): 77.90322580645162
# April(MIN): 45.13333333333333
# April(Max): 76.38333333333334
# May(MIN): 56.91935483870968
# May(Max): 80.25806451612904
# June(MIN): 60.06666666666667
# June(Max): 86.21666666666667
# July(MIN): 62.37096774193548
# July(Max): 85.45161290322581
# August(MIN): 61.225806451612904
# August(MAX): 83.53225806451613
# September(MIN): 52.983333333333334
# September(MAX): 79.78333333333333
# October(MIN): 44.53225806451613
# October(MAX): 77.85483870967742
# November(MIN): 42.53333333333333
# November(MAX): 76.58333333333333
# December(MIN): 36.61290322580645
# December(MAX): 74.56451612903226

# %%
#Mumbai Month Wise Humidity
print('January(MIN):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==1),'low_humidity'].mean()) 
print('January(MAX):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==1),'high_humidity'].mean())
print('Feb(MIN):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==2),'low_humidity'].mean()) 
print('Feb(MAX):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==2),'high_humidity'].mean())
print('March(MIN):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==3),'low_humidity'].mean())
print('March(Max):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==3),'high_humidity'].mean())
print('April(MIN):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==4),'low_humidity'].mean())
print('April(Max):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==4),'high_humidity'].mean())
print('May(MIN):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==5),'low_humidity'].mean())
print('May(Max):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==5),'high_humidity'].mean())
print('June(MIN):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==6),'low_humidity'].mean())
print('June(Max):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==6),'high_humidity'].mean())
print('July(MIN):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==7),'low_humidity'].mean())
print('July(Max):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==7),'high_humidity'].mean())
print('August(MIN):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==8),'low_humidity'].mean())
print('August(MAX):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==8),'high_humidity'].mean())
print('September(MIN):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==9),'low_humidity'].mean())
print('September(MAX):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==9),'high_humidity'].mean())
print('October(MIN):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==10),'low_humidity'].mean())
print('October(MAX):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==10),'high_humidity'].mean())
print('November(MIN):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==11),'low_humidity'].mean())
print('November(MAX):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==11),'high_humidity'].mean())
print('December(MIN):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==12),'low_humidity'].mean())
print('December(MAX):',df1.loc[(df1['city']=='Mumbai') & (df1['month']==12),'high_humidity'].mean())
# Out:
# January(MIN): 24.822580645161292
# January(MAX): 77.2258064516129
# Feb(MIN): 27.57894736842105
# Feb(MAX): 80.08771929824562
# March(MIN): 30.306451612903224
# March(Max): 80.88709677419355
# April(MIN): 41.46666666666667
# April(Max): 82.91666666666667
# May(MIN): 50.38709677419355
# May(Max): 81.5
# June(MIN): 59.8
# June(Max): 89.26666666666667
# July(MIN): 71.59677419354838
# July(Max): 93.96774193548387
# August(MIN): 68.45161290322581
# August(MAX): 92.0
# September(MIN): 64.66666666666667
# September(MAX): 93.26666666666667
# October(MIN): 46.96774193548387
# October(MAX): 88.56451612903226
# November(MIN): 21.7
# November(MAX): 75.13333333333334
# December(MIN): 29.483870967741936
# December(MAX): 80.01612903225806

# %%
#Beijing Month Wise Humidity
print('January(MIN):',df1.loc[(df1['city']=='Beijing') & (df1['month']==1),'low_humidity'].mean()) 
print('January(MAX):',df1.loc[(df1['city']=='Beijing') & (df1['month']==1),'high_humidity'].mean())
print('Feb(MIN):',df1.loc[(df1['city']=='Beijing') & (df1['month']==2),'low_humidity'].mean())
print('Feb(MAX):',df1.loc[(df1['city']=='Beijing') & (df1['month']==2),'high_humidity'].mean())
print('March(MIN):',df1.loc[(df1['city']=='Beijing') & (df1['month']==3),'low_humidity'].mean())
print('March(Max):',df1.loc[(df1['city']=='Beijing') & (df1['month']==3),'high_humidity'].mean())
print('April(MIN):',df1.loc[(df1['city']=='Beijing') & (df1['month']==4),'low_humidity'].mean())
print('April(Max):',df1.loc[(df1['city']=='Beijing') & (df1['month']==4),'high_humidity'].mean())
print('May(MIN):',df1.loc[(df1['city']=='Beijing') & (df1['month']==5),'low_humidity'].mean())
print('May(Max):',df1.loc[(df1['city']=='Beijing') & (df1['month']==5),'high_humidity'].mean())
print('June(MIN):',df1.loc[(df1['city']=='Beijing') & (df1['month']==6),'low_humidity'].mean())
print('June(Max):',df1.loc[(df1['city']=='Beijing') & (df1['month']==6),'high_humidity'].mean())
print('July(MIN):',df1.loc[(df1['city']=='Beijing') & (df1['month']==7),'low_humidity'].mean())
print('July(Max):',df1.loc[(df1['city']=='Beijing') & (df1['month']==7),'high_humidity'].mean())
print('August(MIN):',df1.loc[(df1['city']=='Beijing') & (df1['month']==8),'low_humidity'].mean())
print('August(MAX):',df1.loc[(df1['city']=='Beijing') & (df1['month']==8),'high_humidity'].mean())
print('September(MIN):',df1.loc[(df1['city']=='Beijing') & (df1['month']==9),'low_humidity'].mean())
print('September(MAX):',df1.loc[(df1['city']=='Beijing') & (df1['month']==9),'high_humidity'].mean())
print('October(MIN):',df1.loc[(df1['city']=='Beijing') & (df1['month']==10),'low_humidity'].mean())
print('October(MAX):',df1.loc[(df1['city']=='Beijing') & (df1['month']==10),'high_humidity'].mean())
print('November(MIN):',df1.loc[(df1['city']=='Beijing') & (df1['month']==11),'low_humidity'].mean())
print('November(MAX):',df1.loc[(df1['city']=='Beijing') & (df1['month']==11),'high_humidity'].mean())
print('December(MIN):',df1.loc[(df1['city']=='Beijing') & (df1['month']==12),'low_humidity'].mean())
print('December(MAX):',df1.loc[(df1['city']=='Beijing') & (df1['month']==12),'high_humidity'].mean())
# Out:
# January(MIN): 16.677419354838708
# January(MAX): 73.59677419354838
# Feb(MIN): 10.24561403508772
# Feb(MAX): 63.91228070175438
# March(MIN): 12.338709677419354
# March(Max): 67.03225806451613
# April(MIN): 12.083333333333334
# April(Max): 72.11666666666666
# May(MIN): 15.580645161290322
# May(Max): 78.24193548387096
# June(MIN): 25.983333333333334
# June(Max): 84.5
# July(MIN): 45.87096774193548
# July(Max): 93.0
# August(MIN): 40.70967741935484
# August(MAX): 95.24193548387096
# September(MIN): 31.416666666666668
# September(MAX): 94.75
# October(MIN): 39.66129032258065
# October(MAX): 96.85483870967742
# November(MIN): 21.183333333333334
# November(MAX): 85.48333333333333
# December(MIN): 18.725806451612904
# December(MAX): 78.98387096774194

# %%
#Chicago Month Wise Humidity
print('January(MIN):',df1.loc[(df1['city']=='Chicago') & (df1['month']==1),'low_humidity'].mean()) 
print('January(MAX):',df1.loc[(df1['city']=='Chicago') & (df1['month']==1),'high_humidity'].mean())
print('Feb(MIN):',df1.loc[(df1['city']=='Chicago') & (df1['month']==2),'low_humidity'].mean())
print('Feb(MAX):',df1.loc[(df1['city']=='Chicago') & (df1['month']==2),'high_humidity'].mean())
print('March(MIN):',df1.loc[(df1['city']=='Chicago') & (df1['month']==3),'low_humidity'].mean())
print('March(Max):',df1.loc[(df1['city']=='Chicago') & (df1['month']==3),'high_humidity'].mean())
print('April(MIN):',df1.loc[(df1['city']=='Chicago') & (df1['month']==4),'low_humidity'].mean())
print('April(Max):',df1.loc[(df1['city']=='Chicago') & (df1['month']==4),'high_humidity'].mean())
print('May(MIN):',df1.loc[(df1['city']=='Chicago') & (df1['month']==5),'low_humidity'].mean())
print('May(Max):',df1.loc[(df1['city']=='Chicago') & (df1['month']==5),'high_humidity'].mean())
print('June(MIN):',df1.loc[(df1['city']=='Chicago') & (df1['month']==6),'low_humidity'].mean())
print('June(Max):',df1.loc[(df1['city']=='Chicago') & (df1['month']==6),'high_humidity'].mean())
print('July(MIN):',df1.loc[(df1['city']=='Chicago') & (df1['month']==7),'low_humidity'].mean())
print('July(Max):',df1.loc[(df1['city']=='Chicago') & (df1['month']==7),'high_humidity'].mean())
print('August(MIN):',df1.loc[(df1['city']=='Chicago') & (df1['month']==8),'low_humidity'].mean())
print('August(MAX):',df1.loc[(df1['city']=='Chicago') & (df1['month']==8),'high_humidity'].mean())
print('September(MIN):',df1.loc[(df1['city']=='Chicago') & (df1['month']==9),'low_humidity'].mean())
print('September(MAX):',df1.loc[(df1['city']=='Chicago') & (df1['month']==9),'high_humidity'].mean())
print('October(MIN):',df1.loc[(df1['city']=='Chicago') & (df1['month']==10),'low_humidity'].mean())
print('October(MAX):',df1.loc[(df1['city']=='Chicago') & (df1['month']==10),'high_humidity'].mean())
print('November(MIN):',df1.loc[(df1['city']=='Chicago') & (df1['month']==11),'low_humidity'].mean())
print('November(MAX):',df1.loc[(df1['city']=='Chicago') & (df1['month']==11),'high_humidity'].mean())
print('December(MIN):',df1.loc[(df1['city']=='Chicago') & (df1['month']==12),'low_humidity'].mean())
print('December(MAX):',df1.loc[(df1['city']=='Chicago') & (df1['month']==12),'high_humidity'].mean())
# Out:
# January(MIN): 62.46774193548387
# January(MAX): 86.98387096774194
# Feb(MIN): 50.45614035087719
# Feb(MAX): 83.24561403508773
# March(MIN): 50.29032258064516
# March(Max): 83.59677419354838
# April(MIN): 44.266666666666666
# April(Max): 83.21666666666667
# May(MIN): 43.12903225806452
# May(Max): 84.11290322580645
# June(MIN): 38.2
# June(Max): 82.11666666666666
# July(MIN): 49.62903225806452
# July(Max): 87.48387096774194
# August(MIN): 47.516129032258064
# August(MAX): 87.3225806451613
# September(MIN): 44.43333333333333
# September(MAX): 84.48333333333333
# October(MIN): 52.29032258064516
# October(MAX): 87.04838709677419
# November(MIN): 53.53333333333333
# November(MAX): 85.23333333333333
# December(MIN): 56.193548387096776
# December(MAX): 83.01612903225806

# %%
df1['Crop']=df1['city']

# %%
df1.loc[(df1['city']=='Auckland') & (df1['month']==1),'Crop']='Cabbage'
df1.loc[(df1['city']=='Auckland') & (df1['month']==2),'Crop']='Cabbage'
df1.loc[(df1['city']=='Auckland') & (df1['month']==3),'Crop']='Cabbage'
df1.loc[(df1['city']=='Auckland') & (df1['month']==4),'Crop']='Barley'
df1.loc[(df1['city']=='Auckland') & (df1['month']==5),'Crop']='Barley'
df1.loc[(df1['city']=='Auckland') & (df1['month']==6),'Crop']='Barley'
df1.loc[(df1['city']=='Auckland') & (df1['month']==7),'Crop']='Barley'
df1.loc[(df1['city']=='Auckland') & (df1['month']==8),'Crop']='Barley'
df1.loc[(df1['city']=='Auckland') & (df1['month']==9),'Crop']='Barley'
df1.loc[(df1['city']=='Auckland') & (df1['month']==10),'Crop']='Barley'
df1.loc[(df1['city']=='Auckland') & (df1['month']==11),'Crop']='Barley'
df1.loc[(df1['city']=='Auckland') & (df1['month']==12),'low_humidity']='Citrus'
df1.loc[(df1['city']=='San Diego') & (df1['month']==1),'Crop']='Barley'
df1.loc[(df1['city']=='San Diego') & (df1['month']==2),'Crop']='Citrus'
df1.loc[(df1['city']=='San Diego') & (df1['month']==3),'Crop']='Citrus'
df1.loc[(df1['city']=='San Diego') & (df1['month']==4),'Crop']='Citrus'
df1.loc[(df1['city']=='San Diego') & (df1['month']==5),'Crop']='Citrus'
df1.loc[(df1['city']=='San Diego') & (df1['month']==6),'Crop']='Citrus'
df1.loc[(df1['city']=='San Diego') & (df1['month']==7),'Crop']='Coriander'
df1.loc[(df1['city']=='San Diego') & (df1['month']==8),'Crop']='Coriander'
df1.loc[(df1['city']=='San Diego') & (df1['month']==9),'Crop']='Citrus'
df1.loc[(df1['city']=='San Diego') & (df1['month']==10),'Crop']='Citrus'
df1.loc[(df1['city']=='San Diego') & (df1['month']==11),'Crop']='Citrus'
df1.loc[(df1['city']=='San Diego') & (df1['month']==12),'low_humidity']='Citrus'
df1.loc[(df1['city']=='Mumbai') & (df1['month']==1),'Crop']='Bean'
df1.loc[(df1['city']=='Mumbai') & (df1['month']==2),'Crop']='Bean'
df1.loc[(df1['city']=='Mumbai') & (df1['month']==3),'Crop']='Cashewnut'
df1.loc[(df1['city']=='Mumbai') & (df1['month']==4),'Crop']='Black Gram'
df1.loc[(df1['city']=='Mumbai') & (df1['month']==5),'Crop']='Black Gram'
df1.loc[(df1['city']=='Mumbai') & (df1['month']==6),'Crop']='Cashewnut'
df1.loc[(df1['city']=='Mumbai') & (df1['month']==7),'Crop']='Black Gram'
df1.loc[(df1['city']=='Mumbai') & (df1['month']==8),'Crop']='Black Gram'
df1.loc[(df1['city']=='Mumbai') & (df1['month']==9),'Crop']='Black Gram'
df1.loc[(df1['city']=='Mumbai') & (df1['month']==10),'Crop']='Cashewnut'
df1.loc[(df1['city']=='Mumbai') & (df1['month']==11),'Crop']='Cotton'
df1.loc[(df1['city']=='Mumbai') & (df1['month']==12),'low_humidity']='Bean'
df1.loc[(df1['city']=='Beijing') & (df1['month']==1),'Crop']='None'
df1.loc[(df1['city']=='Beijing') & (df1['month']==2),'Crop']='None'
df1.loc[(df1['city']=='Beijing') & (df1['month']==3),'Crop']='None'
df1.loc[(df1['city']=='Beijing') & (df1['month']==4),'Crop']='None'
df1.loc[(df1['city']=='Beijing') & (df1['month']==5),'Crop']='Bean'
df1.loc[(df1['city']=='Beijing') & (df1['month']==6),'Crop']='Chillies'
df1.loc[(df1['city']=='Beijing') & (df1['month']==7),'Crop']='Cashewnut'
df1.loc[(df1['city']=='Beijing') & (df1['month']==8),'Crop']='Chillies'
df1.loc[(df1['city']=='Beijing') & (df1['month']==9),'Crop']='Bean'
df1.loc[(df1['city']=='Beijing') & (df1['month']==10),'Crop']='Apple'
df1.loc[(df1['city']=='Beijing') & (df1['month']==11),'Crop']='Apple'
df1.loc[(df1['city']=='Beijing') & (df1['month']==12),'low_humidity']='None'
df1.loc[(df1['city']=='Chicago') & (df1['month']==1),'Crop']='Apple'
df1.loc[(df1['city']=='Chicago') & (df1['month']==2),'Crop']='Apple'
df1.loc[(df1['city']=='Chicago') & (df1['month']==3),'Crop']='Apple'
df1.loc[(df1['city']=='Chicago') & (df1['month']==4),'Crop']='Apple'
df1.loc[(df1['city']=='Chicago') & (df1['month']==5),'Crop']='Barley'
df1.loc[(df1['city']=='Chicago') & (df1['month']==6),'Crop']='Bean'
df1.loc[(df1['city']=='Chicago') & (df1['month']==7),'Crop']='Bean'
df1.loc[(df1['city']=='Chicago') & (df1['month']==8),'Crop']='Bean'
df1.loc[(df1['city']=='Chicago') & (df1['month']==9),'Crop']='Cabbage'
df1.loc[(df1['city']=='Chicago') & (df1['month']==10),'Crop']='Apple'
df1.loc[(df1['city']=='Chicago') & (df1['month']==11),'Crop']='Apple'
df1.loc[(df1['city']=='Chicago') & (df1['month']==12),'low_humidity']='Apple'

# %%
df1['Crop'].value_counts()
# Out:
# Barley        612
# Apple         485
# Citrus        483
# Bean          425
# Black Gram    306
# Cashewnut     246
# None          241
# Cabbage       241
# Coriander     124
# Chillies      122
# San Diego      62
# Auckland       62
# Mumbai         62
# Beijing        62
# Chicago        62
# Cotton         60
# Name: Crop, dtype: int64

# %%
df1.shape
# Out:
# (3655, 28)

# %%
df=pd.merge(df1,df2,on='Crop')

# %%
df.head()
# Out:
#    Unnamed: 0      city        date  year  month  day  high_temp  avg_temp  \
# 0           1  Auckland  2016-01-01  2016      1    1         18        65
# 1           2  Auckland  2016-01-02  2016      1    2         18        66
# 2           3  Auckland  2016-01-03  2016      1    3         22        72
# 3           4  Auckland  2016-01-04  2016      1    4         20        66
# 4           5  Auckland  2016-01-05  2016      1    5         18        62
#
#    low_temp  high_dewpt  ...  Season  Rainfall Min   Rainfall Max  \
# 0        15          64  ...  Kharif           380            500
# 1        16          64  ...  Kharif           380            500
# 2        17          70  ...  Kharif           380            500
# 3        14          66  ...  Kharif           380            500
# 4        11          55  ...  Kharif           380            500
#
#    Relative Humidity Max Relative Humidity Max.1  Min Temp  Max Temp  pH Min  \
# ...

# %%
df_=df.loc[:,['city','month','Season','Crop']]

# %%
df_.to_csv('Weather Analysis.csv')

# %%
df.shape
# Out:
# (3044, 38)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3044 entries, 0 to 3043
# Data columns (total 38 columns):
# Unnamed: 0                 3044 non-null int64
# city                       3044 non-null object
# date                       3044 non-null object
# year                       3044 non-null int64
# month                      3044 non-null int64
# day                        3044 non-null int64
# high_temp                  3044 non-null int64
# avg_temp                   3044 non-null int64
# low_temp                   3044 non-null int64
# high_dewpt                 3044 non-null int64
# avg_dewpt                  3044 non-null int64
# low_dewpt                  3044 non-null int64
# high_humidity              3044 non-null int64
# avg_humidity               3044 non-null int64
# low_humidity               3044 non-null object
# high_hg                    3044 non-null float64
# avg_hg                     3044 non-null float64
# ...

# %%
df['Crop'].value_counts()
# Out:
# Barley        612
# Apple         485
# Citrus        483
# Bean          425
# Black Gram    306
# Cashewnut     246
# Cabbage       241
# Coriander     124
# Chillies      122
# Name: Crop, dtype: int64

# %%
#Data Visualization

# %%
plt.figure(figsize=(10,10))
sns.countplot(df['Crop'])

# %%
plt.figure(figsize=(10,10))
sns.countplot(df['Crop'],hue=df['city'])

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'city', 'date', 'year', 'month', 'day', 'high_temp',
#        'avg_temp', 'low_temp', 'high_dewpt', 'avg_dewpt', 'low_dewpt',
#        'high_humidity', 'avg_humidity', 'low_humidity', 'high_hg', 'avg_hg',
#        'low_hg', 'high_vis', 'avg_vis', 'low_vis', 'high_wind', 'avg_wind',
#        'low_wind', 'precip', 'events', 'Temp Diff_x', 'Crop', 'Season',
#        'Rainfall Min', ' Rainfall Max', 'Relative Humidity Max',
#        'Relative Humidity Max.1', 'Min Temp', 'Max Temp', 'pH Min', 'pH Max',
#        'Temp Diff_y'],
#       dtype='object')

# %%
plt.figure(figsize=(10,5))
a=sns.barplot(x='Crop',y='avg_humidity',data=df)
a.set(ylabel='Average Humidity',xlabel='Crop')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='Crop',y='month',hue='city',data=df)

# %%
plt.figure(figsize=(10,5))
a=sns.barplot(x='Crop',y='Temp Diff_y',data=df)
a.set(ylabel='Temperature Difference',xlabel='Crop')
plt.show()

# %%
plt.figure(figsize=(10,5))
a=sns.barplot(x='Crop',y=' Rainfall Max',data=df)
a.set(ylabel='Rainfall Max',xlabel='Crop')
plt.show()

# %%
plt.figure(figsize=(10,5))
a=sns.barplot(x='city',y=' Rainfall Max',data=df)
a.set(ylabel='Rainfall Max',xlabel='City')
plt.show()

# %%
plt.figure(figsize=(10,5))
a=sns.barplot(x='city',y='avg_temp',hue='year',data=df)
a.set(ylabel='Temperature',xlabel='City')
plt.show()

# %%
plt.figure(figsize=(10,5))
a=sns.barplot(x='city',y='avg_humidity',hue='year',data=df)
a.set(ylabel='Temperature',xlabel='City')
plt.show()

# %%
plt.figure(figsize=(10,5))
a=sns.barplot(x='Crop',y='avg_humidity',hue='year',data=df)
a.set(ylabel='Humidity',xlabel='City')
plt.show()

# %%
plt.figure(figsize=(10,5))
a=sns.barplot(x='Crop',y='avg_temp',hue='year',data=df)
a.set(ylabel='Temperature',xlabel='City')
plt.show()

# %%
plt.figure(figsize=(10,5))
a=sns.scatterplot(x='avg_humidity',y='avg_temp',hue='Crop',data=df)
a.set(ylabel='Temperature',xlabel='Humidity')
plt.show()

# %%
plt.figure(figsize=(10,5))
a=sns.scatterplot(x='avg_humidity',y='avg_wind',hue='Crop',data=df)
a.set(ylabel='Wind',xlabel='Humidity')
plt.show()

# %%
plt.figure(figsize=(10,5))
a=sns.scatterplot(x='avg_wind',y='avg_temp',hue='Crop',data=df)
a.set(ylabel='Temperature',xlabel='Wind')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(x='Season',y='Crop',data=df)

# %%
#Correlation Matrix
plt.figure(figsize=(30,30))
sns.heatmap(df.corr(),annot=True)

# %%
df.drop('date',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                 0
# city                       0
# year                       0
# month                      0
# day                        0
# high_temp                  0
# avg_temp                   0
# low_temp                   0
# high_dewpt                 0
# avg_dewpt                  0
# low_dewpt                  0
# high_humidity              0
# avg_humidity               0
# low_humidity               0
# high_hg                    0
# avg_hg                     0
# low_hg                     0
# high_vis                   0
# avg_vis                    0
# low_vis                    0
# high_wind                  0
# avg_wind                   0
# low_wind                   0
# precip                     0
# events                     0
# Temp Diff_x                0
# Crop                       0
# Season                     0
# Rainfall Min               0
#  Rainfall Max              0
# Relative Humidity Max      0
# Relative Humidity Max.1    0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['city']=le.fit_transform(df['city'])
df['precip']=le.fit_transform(df['precip'])
df['events']=le.fit_transform(df['events'])
df['Crop']=le.fit_transform(df['Crop'])
df['Season']=le.fit_transform(df['Season'])

# %%
df['low_humidity']=df['low_humidity'].astype(int)

# %%
#Splitting of data
train=df.drop('Crop',axis=1)
test=df['Crop']

# %%
#Correlation of all varibale against platform variable
train.corrwith(test).plot.bar(figsize=(20,10),
                                           title="Correalation with response variable",
                                           fontsize=15,rot=45,grid=True)

# %%
train.drop(['avg_humidity','avg_hg','Temp Diff_x','Unnamed: 0','events'],axis=1,inplace=True)

# %%
#Correlation of all varibale against platform variable
train.corrwith(test).plot.bar(figsize=(20,10),
                                           title="Correalation with response variable",
                                           fontsize=15,rot=45,grid=True)

# %%
train.drop('date',axis=1,inplace=True)

# %%
train.columns
# Out:
# Index(['city', 'year', 'month', 'day', 'high_temp', 'avg_temp', 'low_temp',
#        'high_dewpt', 'avg_dewpt', 'low_dewpt', 'high_humidity', 'low_humidity',
#        'high_hg', 'low_hg', 'high_vis', 'avg_vis', 'low_vis', 'high_wind',
#        'avg_wind', 'low_wind', 'precip', 'Season', 'Rainfall Min',
#        ' Rainfall Max', 'Relative Humidity Max', 'Relative Humidity Max.1',
#        'Min Temp', 'Max Temp', 'pH Min', 'pH Max', 'Temp Diff_y'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
train1=sc.fit_transform(train)

# %%
from sklearn import model_selection
x_train,x_test,y_train,y_test=model_selection.train_test_split(train1,test,test_size=0.50)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
#Finding Optimal Value of K
x_axis=[]
y_axis=[]

for i in range(1,26,2):
    clf=KNeighborsClassifier(n_neighbors=i)
    score=model_selection.cross_val_score(clf,x_train,y_train)
    x_axis.append(i)
    y_axis.append(score.mean())
    
plt.plot(x_axis,y_axis)
# Out:
# C:\Users\bansa\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# C:\Users\bansa\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# C:\Users\bansa\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# ...

# %%
#TO determine optimal K Value
from sklearn import metrics
for i in range(1,30):
    knn=KNeighborsClassifier(n_neighbors=i)
    model_knn=knn.fit(x_train,y_train)
    pred_knn=model_knn.predict(x_test)
    w=metrics.accuracy_score(pred_knn,y_test)
    print(i)
    print(w)
# Out:
# 1
# 0.9960578186596584
# 2
# 0.9967148488830486
# 3
# 0.9967148488830486
# 4
# 0.9960578186596584
# 5
# 0.9954007884362681
# 6
# 0.9960578186596584
# 7
# 0.9947437582128777
# 8
# 0.9954007884362681
# 9
# 0.9947437582128777
# 10
# 0.9954007884362681
# 11
# 0.9934296977660972
# 12
# 0.9954007884362681
# 13
# 0.992772667542707
# 14
# 0.9954007884362681
# 15
# 0.9940867279894875
# 16
# 0.9967148488830486
# 17
# 0.992772667542707
# 18
# 0.9934296977660972
# 19
# 0.9921156373193167
# 20
# 0.9934296977660972
# 21
# 0.9921156373193167
# 22
# 0.9940867279894875
# 23
# 0.992772667542707
# 24
# 0.9940867279894875
# 25
# 0.9934296977660972
# 26
# 0.9934296977660972
# 27
# 0.9908015768725361
# 28
# 0.9921156373193167
# 29
# 0.9908015768725361

# %%
clf=KNeighborsClassifier(n_neighbors=7)
clf.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=7, p=2,
#                      weights='uniform')

# %%
pred=clf.predict(x_test)

# %%
#Model Evaluation

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       241
#            1       0.99      0.99      0.99       317
#            2       1.00      1.00      1.00       214
#            3       0.99      1.00      1.00       140
#            4       1.00      1.00      1.00       124
#            5       1.00      0.99      1.00       120
#            6       1.00      1.00      1.00        63
#            7       0.99      0.98      0.99       234
#            8       1.00      1.00      1.00        69
#
#     accuracy                           0.99      1522
#    macro avg       1.00      1.00      1.00      1522
# weighted avg       0.99      0.99      0.99      1522

# %%
#Plotting the KNN values
from mlxtend.plotting import plot_decision_regions
from sklearn.decomposition import PCA

y_train2=np.array(y_train)
plt.figure(figsize=(10,10))
pca = PCA(n_components = 2)
x_train2 = pca.fit_transform(x_train)
clf1 = KNeighborsClassifier(n_neighbors=5)
clf1.fit(x_train2, y_train)
plot_decision_regions(x_train2, y_train2, clf=clf1, legend=2)

# %%
#Implementing Ridge, Elastic Net, Gradient Descent Regression Models

# %%
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import Ridge

# %%
en=ElasticNet()
ri=Ridge()

# %%
en.fit(x_train,y_train)
# Out:
# ElasticNet(alpha=1.0, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#            max_iter=1000, normalize=False, positive=False, precompute=False,
#            random_state=None, selection='cyclic', tol=0.0001, warm_start=False)

# %%
ri.fit(x_train,y_train)
# Out:
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
plt.figure(figsize=(10,10))
ft_importances_lm=pd.Series(en.coef_,index=train.columns)
ft_importances_lm.plot(kind='barh')

# %%
plt.figure(figsize=(15,10))
ft_importances_lm=pd.Series(ri.coef_,index=train.columns)
ft_importances_lm.plot(kind='barh')

# %%
ri.score(x_test,y_test)
# Out:
# 0.99953823283184

# %%
en.score(x_test,y_test)
# Out:
# 0.5491083876852886

# %%
en_pred=en.predict(x_test)
ri_pred=ri.predict(x_test)

# %%
en_pred=abs(np.round(en_pred).astype(int))
ri_pred=abs(np.round(ri_pred).astype(int))

# %%
y_test=np.array(y_test)
from sklearn import metrics
y_test=y_test.reshape(1522,)
np.round(metrics.mean_squared_error(y_test,en_pred),2)
# Out:
# 3.44

# %%
metrics.mean_squared_error(y_test,ri_pred)
# Out:
# 0.0

# %%
x=train['pH Max']
y=test
df_temp=pd.DataFrame()

# %%
df_temp['pH']=x
df_temp['Crop']=y

# %%
df_temp=np.array(df_temp)

# %%
def step_gradient(points,learning_rate,m,c):
    m_slope=0
    c_slope=0
    M=len(points)
    for i in range(M):
        x=points[i,0]
        y=points[i,1]
        m_slope=(2/M)*(y-m*x-c)*c
        c_slope+=(-2/M)*(y-m*x-c)
    new_m=m-learning_rate*m_slope
    new_c=c-learning_rate*c_slope
    return new_m,new_c

# %%
def gd(points,learning_rate,num_iteration):
    m=0
    c=0
    for i in range(num_iteration):
        m,c=step_gradient(points,learning_rate,m,c)
        print(i,"Cost",cost(points,m,c))
    return m,c

# %%
def cost(points,m,c):
    total_cost=0
    M=len(points)
    for i in range(M):
        x=points[i,0]
        y=points[i,1]
        total_cost=(1/M)*((y-m*x-c)**2)
    return total_cost

# %%
def run():
    learning_rate=0.004
    num_iteration=50
    m,c=gd(df_temp,learning_rate,num_iteration)
    print(m,c)

# %%
run()
# Out:
# 0 Cost 0.020891473638805558
# 1 Cost 0.02075949040982701
# 2 Cost 0.02062899817624865
# 3 Cost 0.020499977925960835
# 4 Cost 0.020372410915869624
# 5 Cost 0.020246278667785177
# 6 Cost 0.020121562964376522
# 7 Cost 0.019998245845191755
# 8 Cost 0.019876309602742247
# 9 Cost 0.01975573677865022
# 10 Cost 0.019636510159858168
# 11 Cost 0.019518612774899385
# 12 Cost 0.019402027890228546
# 13 Cost 0.019286739006611073
# 14 Cost 0.01917272985557075
# 15 Cost 0.019059984395894063
# 16 Cost 0.018948486810190887
# 17 Cost 0.01883822150151007
# 18 Cost 0.018729173090009286
# 19 Cost 0.018621326409678243
# 20 Cost 0.01851466650511417
# 21 Cost 0.018409178628348895
# 22 Cost 0.01830484823572658
# 23 Cost 0.018201660984831242
# 24 Cost 0.018099602731463264
# 25 Cost 0.017998659526664084
# 26 Cost 0.017898817613788264
# 27 Cost 0.01780006342562207
# 28 Cost 0.017702383581547913
# 29 Cost 0.017605764884753818
# 30 Cost 0.01751019431948713
# 31 Cost 0.017415659048351892
# ...
